# %% [markdown]
# <a href="https://colab.research.google.com/github/Playingintr/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadística**
#
# ##Grupo: 2Y
# ## **Unidad 1**
# Docente: Jose Gabriel Rodriguez Rivas.
# Alumno: Dominguez Lopez Christian Bryan.
# **Practica 1 - Medidas de Tendencia Central e Histogamas**

# %%
from statistics import *
#Libreria para generar numeros aleatorios
import random
#Libreria de phyton para graficar valores
#as para asignar un alias
import matplotlib.pyplot as plt

#Lista de calificaciones del grupo a de probabilidad
grupoa=[70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
#La función nos devuelve el tipo de dato de la variable
type(grupoa)
#Sacar la media de las calificaciones con una formula
promedio=sum(grupoa)/len(grupoa)
print(promedio)
#Utilizar la funcion mean que esta en la libreria statistics para calcular el promedio
promedio2=mean(grupoa)
print(promedio2)
#Determinar el valor de la mediana con la funcion median
mediana=median(grupoa)
print(mediana)
#Determinar el valor de la moda
moda=mode(grupoa)
print(moda)
#En caso de que exista más de una moda
#Múltiples modas que puedan existir
moda2=multimode(grupoa)
print(moda2)

#Tiempos wue tardaron losalumnos
tiempos100mts=[15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.3, 15.10, 17.20]
print(tiempos100mts)
#Utilizamos la funcion mean para determinar el tiempo promedio
print("El tiempo promedio de los corredores es =>",mean(tiempos100mts))
#Definimos una variabl3 llamada mediana para calcular la mediana con la funciôn median
mediana=median(tiempos100mts)
print("La media de los tiempos delos corredores es=>", mediana)
#definimos una variable llamada moda para calcular la moda con la función mode
moda=mode(tiempos100mts)
print("La moda de pos tiempos es=>", moda)
multimodas=multimode(tiempos100mts)
print("La moda de los tiempos es=>", multimodas)

fabrica1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
#Plotter
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
fabrica2=[]
for i in range(100):
  numero_aleatorio2=round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)




media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Valores de la fabrica 1")
print("La media es: ", media1)
print("a mediana es: ", mediana1)
print("La moda es: ", moda1)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.3, 15.1, 17.2]
# El tiempo promedio de los corredores es => 17.287
# La media de los tiempos delos corredores es=> 17.2
# La moda de pos tiempos es=> 15.1
# La moda de los tiempos es=> [15.1, 17.2]
# [57.25, 99.32, 66.01, 62.82, 52.46, 86.49, 86.42, 63.22, 52.08, 62.2, 71.4, 96.71, 55.25, 67.97, 74.59, 96.04, 82.85, 94.49, 83.43, 80.05, 98.3, 77.17, 82.43, 65.12, 91.05, 90.2, 74.8, 73.74, 93.84, 61.59, 76.56, 98.29, 79.88, 79.87, 61.3, 75.36, 69.32, 54.19, 55.52, 58.19, 79.06, 91.95, 58.75, 87.51, 53.56, 65.73, 57.13, 57.01, 50.19, 97.75, 53.99, 79.71, 57.66, 91.31, 69.77, 88.83, 77.63, 80.58, 85.95, 52.74, 70.61, 71.19, 93.69, 61.56, 80.52, 62.65, 89.86, 98.12, 77.66, 56.11, 61.34, 97.35, 90.08, 79.02, 79.18, 74.19, 78.6, 88.9, 98.42, 64.79, 57.92, 99.38, 81.29, 57.94, 81.88, 95.2, 58.58, 67.94, 85.2, 80.74, 55.9, 71.49, 84.77, 92.71, 64.46, 66.1, 54.03, 84.66, 79.44, 70.49]
# [51.62, 88.97, 43.97, 45.06, 54.93, 66.07, 50.43, 76.12, 67.61, 74.03, 43.45, 49.27, 63.01, 76.93, 73.58, 51.66, 66.03, 53.32, 56.67, 44.4, 42.22, 50.04, 78.95, 61.65, 55.47, 49.19, 47.75, 52.01, 77.95, 91.23, 58.0, 88.47, 70.55, 74.34, 44.8, 82.77, 59.06, 86.13, 64.83, 48.29, 85.55, 81.17, 50.9, 67.65, 55.95, 67.1, 67.6, 44.98, 77.78, 89.3, 63.29, 75.28, 72.79, 88.77, 77.97, 52.56, 49.78, 49.08, 84.71, 52.64, 44.02, 82.2, 62.21, 56.38, 76.37, 43.54, 47.29, 71.09, 79.16, 43.45, 75.67, 72.18, 80.85, 82.72, 59.44, 41.22, 57.71, 75.25, 59.88, 42.63, 47.59, 69.07, 53.18, 40.52, 78.67, 88.07, 53.82, 58.92, 43.01, 46.27, 54.37, 52.67, 47.41, 56.25, 90.06, 67.04, 72.81, 83.18, 77.49, 46.16]
# Valores de la fabrica 1
# La media es:  75.08539999999999
# a mediana es:  76.86500000000001
# La moda es:  57.25

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Valores de la fabrica 2")
print("La media es: ", media2)
print("a mediana es: ", mediana2)
print("La moda es: ", moda2)
# Out:
# Valores de la fabrica 2
# La media es:  63.155
# a mediana es:  60.765
# La moda es:  43.45

# %%
#Generar 2 subplots de 1 renglon por 2 columnas para desplegar los histogramas, una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producion diaria de la fabrica 1')
#Mostrar caja con leyendas
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producion diaria de la fabrica 2')
#Mostrar caja con leyendas
plt.legend()
plt.show()

# %%
# Out:
# [70, 100]
