# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadística**
#
# ## **Unidad 1**
#
# ### **Práctica 3 - Tabla de Frecuencias y Regla de Sturges..**
#
# Docente: Jose Gabriel Rodríguez Rivas.
#
# Alumno: Domínguez López Christian Bryan.
#
# Grupo: 2Y

# %%
#Basado en el libro 'Estadistica para Administracion', en la pagina 47.
#Creamos una lista vacia que representa la edad de 100 personas.
import random
import pandas as pd
import matplotlib.pyplot as plt
edades=[]
#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas.
for i in range(100):
  #Generamos un numero aleatorio con la funcion randint y lo guardamos en la variable 'numero_aleatorio'.
  numero_aleatorio=random.randint(18,70)
  #Agregamos el numero aleatorio a la lista de valores.
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [34, 33, 42, 69, 38, 45, 18, 51, 41, 64, 20, 28, 31, 59, 18, 64, 26, 19, 44, 19, 33, 32, 36, 70, 37, 50, 35, 48, 54, 48, 50, 30, 38, 20, 49, 38, 63, 49, 30, 36, 31, 48, 67, 25, 58, 52, 64, 19, 29, 53, 19, 41, 40, 37, 21, 23, 43, 57, 54, 24, 23, 59, 58, 50, 36, 23, 24, 70, 37, 46, 61, 38, 42, 37, 29, 21, 54, 47, 47, 24, 26, 51, 39, 37, 51, 35, 60, 62, 52, 66, 36, 63, 47, 18, 69, 47, 54, 66, 46, 63]

# %%
#Crear un DataFrame de pandas con los numeros aleatorios.
df=pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    34
# 1    33
# 2    42
# 3    69
# 4    38

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad', 'Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')
#Imprimir la tabla de distribucion de frecuencias
print("Tabla de Distribucion de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 6     18           3
# 1     19           4
# 19    20           2
# 17    21           2
# 12    23           3
# 13    24           3
# 35    25           1
# 18    26           2
# 32    28           1
# 31    29           2
# 26    30           2
# 22    31           2
# 37    32           1
# 23    33           2
# 33    34           1
# 29    35           2
# 4     36           4
# 0     37           5
# 2     38           4
# 44    39           1
# 42    40           1
# 20    41           2
# 14    42           2
# 40    43           1
# 38    44           1
# 34    45           1
# 16    46           2
# 5     47           4
# 9     48           3
# 25    49           2
# 8     50           3
# 10    51           3
# 27    52           2
# 41    53           1
# 3     54           4
# 39    57           1
# 28    58           2
# 21    59           2
# 45    60           1
# 43    61           1
# 46    62           1
# 7     63           3
# 11    64           3
# 15    66           2
# 36    67           1
# 24    69           2
# 30    70           2

# %%
#Calcular la frecuencia relativa
tabla_frecuencias['Frec. Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 6     18           3            0.03
# 1     19           4            0.04
# 19    20           2            0.02
# 17    21           2            0.02
# 12    23           3            0.03
# 13    24           3            0.03
# 35    25           1            0.01
# 18    26           2            0.02
# 32    28           1            0.01
# 31    29           2            0.02
# 26    30           2            0.02
# 22    31           2            0.02
# 37    32           1            0.01
# 23    33           2            0.02
# 33    34           1            0.01
# 29    35           2            0.02
# 4     36           4            0.04
# 0     37           5            0.05
# 2     38           4            0.04
# 44    39           1            0.01
# 42    40           1            0.01
# 20    41           2            0.02
# 14    42           2            0.02
# 40    43           1            0.01
# 38    44           1            0.01
# 34    45           1            0.01
# 16    46           2            0.02
# 5     47           4            0.04
# 9     48           3            0.03
# 25    49           2            0.02
# 8     50           3            0.03
# 10    51           3            0.03
# 27    52           2            0.02
# 41    53           1            0.01
# 3     54           4            0.04
# 39    57           1            0.01
# 28    58           2            0.02
# 21    59           2            0.02
# 45    60           1            0.01
# 43    61           1            0.01
# 46    62           1            0.01
# 7     63           3            0.03
# 11    64           3            0.03
# 15    66           2            0.02
# 36    67           1            0.01
# 24    69           2            0.02
# 30    70           2            0.02

# %%
#Calcular la frecuencia porcentual
tabla_frecuencias['Frec. Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual
# 6     18           3            0.03               3.0
# 1     19           4            0.04               4.0
# 19    20           2            0.02               2.0
# 17    21           2            0.02               2.0
# 12    23           3            0.03               3.0
# 13    24           3            0.03               3.0
# 35    25           1            0.01               1.0
# 18    26           2            0.02               2.0
# 32    28           1            0.01               1.0
# 31    29           2            0.02               2.0
# 26    30           2            0.02               2.0
# 22    31           2            0.02               2.0
# 37    32           1            0.01               1.0
# 23    33           2            0.02               2.0
# 33    34           1            0.01               1.0
# 29    35           2            0.02               2.0
# 4     36           4            0.04               4.0
# 0     37           5            0.05               5.0
# 2     38           4            0.04               4.0
# 44    39           1            0.01               1.0
# 42    40           1            0.01               1.0
# 20    41           2            0.02               2.0
# 14    42           2            0.02               2.0
# 40    43           1            0.01               1.0
# 38    44           1            0.01               1.0
# 34    45           1            0.01               1.0
# 16    46           2            0.02               2.0
# 5     47           4            0.04               4.0
# 9     48           3            0.03               3.0
# 25    49           2            0.02               2.0
# 8     50           3            0.03               3.0
# 10    51           3            0.03               3.0
# 27    52           2            0.02               2.0
# 41    53           1            0.01               1.0
# 3     54           4            0.04               4.0
# 39    57           1            0.01               1.0
# 28    58           2            0.02               2.0
# 21    59           2            0.02               2.0
# 45    60           1            0.01               1.0
# 43    61           1            0.01               1.0
# 46    62           1            0.01               1.0
# 7     63           3            0.03               3.0
# 11    64           3            0.03               3.0
# 15    66           2            0.02               2.0
# 36    67           1            0.01               1.0
# 24    69           2            0.02               2.0
# 30    70           2            0.02               2.0

# %%
#Calcular la frecuencia acumulada
tabla_frecuencias['Frec. Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Acumulada
# 6     18           3            0.03               3.0                3
# 1     19           4            0.04               4.0                7
# 19    20           2            0.02               2.0                9
# 17    21           2            0.02               2.0               11
# 12    23           3            0.03               3.0               14
# 13    24           3            0.03               3.0               17
# 35    25           1            0.01               1.0               18
# 18    26           2            0.02               2.0               20
# 32    28           1            0.01               1.0               21
# 31    29           2            0.02               2.0               23
# 26    30           2            0.02               2.0               25
# 22    31           2            0.02               2.0               27
# 37    32           1            0.01               1.0               28
# 23    33           2            0.02               2.0               30
# 33    34           1            0.01               1.0               31
# 29    35           2            0.02               2.0               33
# 4     36           4            0.04               4.0               37
# 0     37           5            0.05               5.0               42
# 2     38           4            0.04               4.0               46
# 44    39           1            0.01               1.0               47
# 42    40           1            0.01               1.0               48
# 20    41           2            0.02               2.0               50
# 14    42           2            0.02               2.0               52
# 40    43           1            0.01               1.0               53
# 38    44           1            0.01               1.0               54
# 34    45           1            0.01               1.0               55
# 16    46           2            0.02               2.0               57
# 5     47           4            0.04               4.0               61
# 9     48           3            0.03               3.0               64
# 25    49           2            0.02               2.0               66
# 8     50           3            0.03               3.0               69
# 10    51           3            0.03               3.0               72
# 27    52           2            0.02               2.0               74
# 41    53           1            0.01               1.0               75
# 3     54           4            0.04               4.0               79
# 39    57           1            0.01               1.0               80
# 28    58           2            0.02               2.0               82
# 21    59           2            0.02               2.0               84
# 45    60           1            0.01               1.0               85
# 43    61           1            0.01               1.0               86
# 46    62           1            0.01               1.0               87
# 7     63           3            0.03               3.0               90
# 11    64           3            0.03               3.0               93
# 15    66           2            0.02               2.0               95
# 36    67           1            0.01               1.0               96
# 24    69           2            0.02               2.0               98
# 30    70           2            0.02               2.0              100

# %% [markdown]
# ##Regla de Sturges
# 1. Es una regla que sirve para calcular el numero de clases o intervalos idoneo en los que se debe dividir un conjunto de datos.
# 2. Establece que el **numero de clases es igual a uno mas el logaritmo en base dos del numero total de datos**.
#
# *c=1+log₂(N)*
#
# donde 'N' es el tamaño de la muestra.

# %%
#Importamos la libreria math de funciones matematicas.
import math

# %%
#Volvemos a usar la libreria edades
print(edades)
# Out:
# [34, 33, 42, 69, 38, 45, 18, 51, 41, 64, 20, 28, 31, 59, 18, 64, 26, 19, 44, 19, 33, 32, 36, 70, 37, 50, 35, 48, 54, 48, 50, 30, 38, 20, 49, 38, 63, 49, 30, 36, 31, 48, 67, 25, 58, 52, 64, 19, 29, 53, 19, 41, 40, 37, 21, 23, 43, 57, 54, 24, 23, 59, 58, 50, 36, 23, 24, 70, 37, 46, 61, 38, 42, 37, 29, 21, 54, 47, 47, 24, 26, 51, 39, 37, 51, 35, 60, 62, 52, 66, 36, 63, 47, 18, 69, 47, 54, 66, 46, 63]

# %%
#Crear un DataFrame con las edades
df=pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     34
# 1     33
# 2     42
# 3     69
# 4     38
# ..   ...
# 95    47
# 96    54
# 97    66
# 98    46
# 99    63
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de intervalos utilizando la regla de Sturges
n=len(edades)
K=int(1+math.log2(n))
print("Valor de n=",n,"\nNumero de intervalos=",K)
# Out:
# Valor de n= 100
# Numero de intervalos= 7

# %%
#Crear la tabla de frecuencia
tabla_frecuencia=pd.cut(df['Edad'],bins=K,include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    20
# 1  (17.947, 25.429]    18
# 2  (47.714, 55.143]    18
# 3    (62.571, 70.0]    13
# 4  (40.286, 47.714]    13
# 5  (25.429, 32.857]    10
# 6  (55.143, 62.571]     8

# %%
#Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    18
# 5  (25.429, 32.857]    10
# 0  (32.857, 40.286]    20
# 4  (40.286, 47.714]    13
# 2  (47.714, 55.143]    18
# 6  (55.143, 62.571]     8
# 3    (62.571, 70.0]    13

# %%
#Generar columnas siguientes
tabla_frecuencia['Frec. Relativa']=tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec. Porcentual']=tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec. Acumulada']=tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec. Relativa Acumulada']=tabla_frecuencia['Frec. Relativa'].cumsum()
tabla_frecuencia['Frec. Porcentual Acumulada']=tabla_frecuencia['Frec. Porcentual'].cumsum()
#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec. Relativa  Frec. Porcentual  Frec. Acumulada  \
# 1  (17.947, 25.429]    18            0.18              18.0               18
# 5  (25.429, 32.857]    10            0.10              10.0               28
# 0  (32.857, 40.286]    20            0.20              20.0               48
# 4  (40.286, 47.714]    13            0.13              13.0               61
# 2  (47.714, 55.143]    18            0.18              18.0               79
# 6  (55.143, 62.571]     8            0.08               8.0               87
# 3    (62.571, 70.0]    13            0.13              13.0              100
#
#    Frec. Relativa Acumulada  Frec. Porcentual Acumulada
# 1                      0.18                        18.0
# 5                      0.28                        28.0
# 0                      0.48                        48.0
# 4                      0.61                        61.0
# 2                      0.79                        79.0
# 6                      0.87                        87.0
# 3                      1.00                       100.0

# %%
plt.hist(edades, alpha=0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
#Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title('Histograma de edades basado en la Regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
