# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadística**
#
# ##Grupo: 2Y
# ## **Unidad 1**
# Docente: Jose Gabriel Rodríguez Rivas.
#
# Alumno: Domínguez López Christian Bryan.
#
# **Práctica 2 - Diagramas de Cajas y Bigotes**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [63.12, 65.14, 88.53, 98.05, 93.23, 57.49, 93.97, 87.31, 62.26, 98.2, 59.98, 65.79, 71.76, 78.67, 83.21, 57.55, 64.51, 54.51, 77.66, 58.31, 87.61, 66.9, 53.91, 92.75, 92.37, 50.34, 98.93, 95.46, 67.49, 57.45, 68.91, 61.97, 81.65, 95.56, 58.47, 76.55, 60.13, 98.82, 92.29, 84.02, 95.95, 55.05, 86.39, 82.07, 77.29, 60.41, 81.82, 72.61, 91.91, 78.04, 54.08, 93.12, 81.53, 69.96, 76.69, 79.64, 97.09, 62.99, 80.61, 91.92, 68.35, 51.14, 83.86, 71.3, 93.27, 81.26, 89.71, 77.78, 78.59, 87.26, 65.19, 67.65, 78.84, 57.71, 61.51, 59.71, 89.51, 86.53, 88.11, 86.59, 68.73, 50.53, 69.08, 54.43, 94.57, 84.64, 68.5, 75.0, 56.61, 51.65, 92.52, 54.41, 61.46, 50.82, 52.64, 92.33, 74.42, 72.66, 64.75, 68.66]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(40, 93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [46.0, 82.5, 80.77, 40.49, 92.2, 43.88, 87.15, 41.08, 50.59, 77.81, 66.16, 81.75, 63.33, 69.55, 91.37, 74.33, 51.52, 92.41, 56.86, 46.75, 81.15, 68.63, 72.61, 92.29, 47.79, 57.65, 43.5, 86.09, 85.39, 43.87, 77.84, 84.1, 50.34, 46.57, 77.22, 73.22, 42.37, 56.42, 71.75, 74.08, 86.65, 70.85, 44.37, 73.62, 48.72, 90.31, 59.9, 80.4, 69.64, 91.55, 60.27, 53.52, 55.1, 43.95, 64.44, 80.44, 40.05, 68.1, 84.04, 91.59, 51.99, 83.32, 42.49, 55.56, 60.04, 41.0, 48.07, 82.29, 84.89, 78.68, 81.72, 51.38, 67.26, 68.01, 56.52, 74.17, 74.34, 50.23, 58.18, 52.85, 54.65, 91.7, 60.74, 44.77, 86.01, 66.37, 49.52, 85.83, 56.23, 63.5, 67.9, 55.72, 76.78, 52.18, 74.67, 69.59, 62.17, 63.96, 83.65, 86.97]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion en la fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Produccion en mts.')
plt.title('Produccion en la fabrica 2')
plt.show()

# %% [markdown]
# Comparamos la produccion de la fabrica 1 y la fabrica 2 en un script

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(fabrica1,
                   vert=True, #Alineacion vertical
                   patch_artist=True)#Rellenar con color
ax1.set_title('Produccion fabrica 1')
bplot2=ax2.boxplot(fabrica2,
                   vert=True, #Alineacion vertical
                   patch_artist=True)#Rellenar con color
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
#Insertamos un valor de 150 a la fabrica 1. Seria un valor atipico
fabrica1.append(150)
print(fabrica1)
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(fabrica1,
                   vert=True, #Alineacion vertical
                   patch_artist=True)#Rellenar con color
ax1.set_title('Produccion fabrica 1')
bplot2=ax2.boxplot(fabrica2,
                   vert=True, #Alineacion vertical
                   patch_artist=True)#Rellenar con color
ax2.set_title('Produccion fabrica 2')
plt.show()
# Out:
# [63.12, 65.14, 88.53, 98.05, 93.23, 57.49, 93.97, 87.31, 62.26, 98.2, 59.98, 65.79, 71.76, 78.67, 83.21, 57.55, 64.51, 54.51, 77.66, 58.31, 87.61, 66.9, 53.91, 92.75, 92.37, 50.34, 98.93, 95.46, 67.49, 57.45, 68.91, 61.97, 81.65, 95.56, 58.47, 76.55, 60.13, 98.82, 92.29, 84.02, 95.95, 55.05, 86.39, 82.07, 77.29, 60.41, 81.82, 72.61, 91.91, 78.04, 54.08, 93.12, 81.53, 69.96, 76.69, 79.64, 97.09, 62.99, 80.61, 91.92, 68.35, 51.14, 83.86, 71.3, 93.27, 81.26, 89.71, 77.78, 78.59, 87.26, 65.19, 67.65, 78.84, 57.71, 61.51, 59.71, 89.51, 86.53, 88.11, 86.59, 68.73, 50.53, 69.08, 54.43, 94.57, 84.64, 68.5, 75.0, 56.61, 51.65, 92.52, 54.41, 61.46, 50.82, 52.64, 92.33, 74.42, 72.66, 64.75, 68.66, 150, 150, 150]

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,5))
bplot1=ax1.boxplot(fabrica1,
                   vert=True, #Alineacion vertical
                   patch_artist=True)#Rellenar con color
ax1.set_title('Produccion fabrica 1')
ax1.set_ylim(0,160)#Escala uniforme
bplot2=ax2.boxplot(fabrica2,
                   vert=True, #Alineacion vertical
                   patch_artist=True)#Rellenar con color
ax2.set_title('Produccion fabrica 2')
ax2.set_ylim(0,160)#Escala uniforme
plt.show()
