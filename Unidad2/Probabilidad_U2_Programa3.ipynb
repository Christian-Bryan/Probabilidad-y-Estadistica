# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad2/Probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadística**
#
# ##Grupo: 2Y
# ## **Unidad 2**
# Docente: Jose Gabriel Rodriguez Rivas.
#
# Alumno: Dominguez Lopez Christian Bryan.
#
# **Practica 3 - Ejercicio**

# %%
import math as mt #Para utilizar factorial
from itertools import permutations
from itertools import product
import numpy as np

# %%
asistentes=["John", "Samantha", "Lucas", "Christian", "Maria", "Helena", "Jacob", "Bryan", "Edgar", "Isabella"]
n=len(asistentes)
r=4
pr=mt.factorial(n)/(mt.factorial(n-r))
print("Hay ",pr," maneras posibles de elegir a los asistentes para calificar el primer examen, habiendo",n,"asistentes y teniendo ",r," preguntas.")
print("Aqui las permutaciones en grupos de ",r," en ",r,".")
permutaciones_asistentes=list(permutations(asistentes, r))
for permutacion in permutaciones_asistentes:
  print(permutacion)
# Out:
# Hay  5040.0  maneras posibles de elegir a los asistentes para calificar el primer examen, habiendo 10 asistentes y teniendo  4  preguntas.
# Aqui las permutaciones en grupos de  4  en  4 .
# ('John', 'Samantha', 'Lucas', 'Christian')
# ('John', 'Samantha', 'Lucas', 'Maria')
# ('John', 'Samantha', 'Lucas', 'Helena')
# ('John', 'Samantha', 'Lucas', 'Jacob')
# ('John', 'Samantha', 'Lucas', 'Bryan')
# ('John', 'Samantha', 'Lucas', 'Edgar')
# ('John', 'Samantha', 'Lucas', 'Isabella')
# ('John', 'Samantha', 'Christian', 'Lucas')
# ('John', 'Samantha', 'Christian', 'Maria')
# ('John', 'Samantha', 'Christian', 'Helena')
# ('John', 'Samantha', 'Christian', 'Jacob')
# ('John', 'Samantha', 'Christian', 'Bryan')
# ('John', 'Samantha', 'Christian', 'Edgar')
# ('John', 'Samantha', 'Christian', 'Isabella')
# ('John', 'Samantha', 'Maria', 'Lucas')
# ('John', 'Samantha', 'Maria', 'Christian')
# ('John', 'Samantha', 'Maria', 'Helena')
# ('John', 'Samantha', 'Maria', 'Jacob')
# ...
