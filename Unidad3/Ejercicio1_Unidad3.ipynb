# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad3/Ejercicio1_Unidad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadística**
#
# ##Grupo: 2Y
# ## **Unidad 3**
# Docente: Jose Gabriel Rodriguez Rivas.
#
# Alumno: Dominguez Lopez Christian Bryan.
#
# **Ejercicio 1**

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x=[0, 1, 2, 3, 4, 5]
p=[0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
#Verificar que las probabilidades sumen uno
print("Suma de probabilidades", sum(p))
# Out:
# Suma de probabilidades 1.0

# %%
#Elaborar la distribucion de probabilidad de x
plt.stem(x,p)
plt.title("Distribucion de probabilidad")
plt.xlabel("Numero de celulas anormales")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()

# %%
#Calcular el valor esperado E(X) (promedio de celulas anormales por muestra).
valor_esperado=0
#Recorrer sus valores y sus probabilidades
for i in range(len(x)):
  xi=x[i] #Valor de la variable aleatoria
  pi=p[i] #Probabilidad de ese valor
  producto=xi*pi #Multiplicar valor por su probabilidad
  valor_esperado+=producto #Sumar al acumulador
  #Mostrar cada paso
  print(f"x={xi}, p={pi}, x*p={producto:.2f}")
#Mostrar resultado final
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x=0, p=0.1, x*p=0.00
# x=1, p=0.25, x*p=0.25
# x=2, p=0.3, x*p=0.60
# x=3, p=0.2, x*p=0.60
# x=4, p=0.1, x*p=0.40
# x=5, p=0.05, x*p=0.25
#
# Valor esperado (Esperanza): 2.10

# %%
esperanza_cuadrado=0
for i in range(len(x)):
  esperanza_cuadrado+=(x[i]**2)*p[i]
  #Calcular la varianza y la desviacion estandar
  varianza=esperanza_cuadrado-valor_esperado**2
desviación=math.sqrt(varianza)
print(f"E(X)= {valor_esperado:.2f}")
print(f"E(X^2)= {esperanza_cuadrado:.2f}")
print(f"Varianza= {varianza:.2f}")
print(f"Desviación estándar= {desviación:.2f}")
# Out:
# E(X)= 2.10
# E(X^2)= 6.10
# Varianza= 1.69
# Desviación estándar= 1.30

# %%
#Construir la funcion de distribucion acumulada F(x) y representarla graficamente
F=np.cumsum(p)
#Mostrar resultados
for xi, fi in zip(x, F):
  print(F"f({xi})={fi:.2f}")
#Graficar
plt.step(x, F, where='post')
plt.title("Funcion de Distribucion Acumulada (FDA)")
plt.xlabel("Numero de celulas anormales")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# f(0)=0.10
# f(1)=0.35
# f(2)=0.65
# f(3)=0.85
# f(4)=0.95
# f(5)=1.00

# %%
#Interpretar los resultados en el contexto biomedico
#Cual es el promedio esperado de celulas anormales por muestra?
#2.10
#Existe mucha variabilidad entre las muestras?
#Es moderada, porque los valores se agrupan cerca del promedio
#Que indica la funcion acumulada sobre la propiedad de encontrar un numero bajo o alto de celulas anormales?
#Que la mayoría de las muestras presentan pocos casos anormales (0 a 2). Los valores altos (4 o 5 células anormales) son poco frecuentes.
