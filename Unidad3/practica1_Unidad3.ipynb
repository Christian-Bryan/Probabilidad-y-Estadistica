# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad3/practica1_Unidad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
#Valores de la varieble aleatoria
x=[5, 6, 7, 8, 9, 10]
p=[0.05, 0.30, 0.20, 0.30, 0.25, 0.10]
#Verificar suma=1
print("Suma de probabilidades", sum(p))
#Graficar distribucion
plt.stem(x,p)
plt.title("Distribucion de probabilidad")
plt.xlabel("Calificacion")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades 1.2
