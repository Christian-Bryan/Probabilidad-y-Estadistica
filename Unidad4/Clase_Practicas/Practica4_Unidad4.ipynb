# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad4/Clase_Practicas/Practica4_Unidad4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import poisson

#Parámetros de la distribución de Poisson
media_accidentes=2

#Parte 1: Probabilidad de que no haya accidentes en una semana
probabilidad_0_accidentes=poisson.pmf(0, media_accidentes)

print("1. Probabilidad de que no haya accidentes en una semana:", probabilidad_0_accidentes)

#Parte 2: Probabilidad de que a lo sumo haya tres accidentes en dos semanas
#Convertimos la media a una media para dos semanas
media_2_semanas=media_accidentes*2

#Calculamos la probabilidad acumulada hasta 3 accidentes en dos semanas
probabilidad_3_o_menos_accidentes=poisson.cdf(3, media_2_semanas)

print("2. Probabilidad de que a lo sumo haya tres accidentes en 2 semanas:", probabilidad_3_o_menos_accidentes)
# Out:
# 1. Probabilidad de que no haya accidentes en una semana: 0.1353352832366127
# 2. Probabilidad de que a lo sumo haya tres accidentes en 2 semanas: 0.43347012036670896
