# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Bryan/Probabilidad-y-Estadistica/blob/main/Unidad5/Ejercicio_Unidad5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadística**
#
# ##Grupo: 2Y
# ## **Unidad 5**
# Docente: Jose Gabriel Rodriguez Rivas.
#
# Alumno: Dominguez Lopez Christian Bryan.
#
# **Ejercicio - Regresion y Correlacion**

# %% [markdown]
# Carga y exploracion de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
#Cargando el primer archivo como DataFrame
df1=pd.read_csv("grupo1.csv")
df1.head()
# Out:
#    HorasEstudio  Calificacion
# 0         20.00         75.94
# 1         15.60         87.48
# 2         17.91         79.40
# 3         20.00         73.37
# 4         20.00         83.75

# %%
#Cargando el segundo archivo como DataFrame
df2=pd.read_csv("grupo2.csv")
df2.head()
# Out:
#    HorasEstudio  Calificacion
# 0          3.79          40.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8

# %%
#Cargando el tercer archivo como DataFrame
df3=pd.read_csv("grupo3.csv")
df3.head()
# Out:
#    HorasEstudio  Calificacion
# 0          3.79          15.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8

# %%
#Realizando descripcion estadistica de la columna calificaciones
df1.Calificacion.describe()
# Out:
# count     50.00000
# mean      83.78820
# std        7.83389
# min       68.46000
# 25%       78.03500
# 50%       84.49000
# 75%       88.09000
# max      100.00000
# Name: Calificacion, dtype: float64

# %%
#Realizando descripcion estadistica de la columna calificaciones
df2.Calificacion.describe()
# Out:
# count    50.000000
# mean     75.912000
# std      20.668922
# min      26.100000
# 25%      63.500000
# 50%      78.550000
# 75%      93.300000
# max      99.000000
# Name: Calificacion, dtype: float64

# %%
#Realizando descripcion estadistica de la columna calificaciones
df3.Calificacion.describe()
# Out:
# count    50.000000
# mean     75.968000
# std      23.668867
# min      15.000000
# 25%      61.000000
# 50%      84.950000
# 75%      94.375000
# max      99.000000
# Name: Calificacion, dtype: float64

# %%
#Generando histograma de calificaciones del grupo 1
from matplotlib import pyplot
media1=df1.Calificacion.mean()
plt.hist(df1.Calificacion, bins=7)
plt.title("Calificaciones del grupo 1")
plt.axvline(media1, color='y', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.xlabel("Calificaciones")
# Out:
# Text(0.5, 0, 'Calificaciones')

# %%
#Generando histograma de calificaciones del grupo 2
media2=df2.Calificacion.mean()
plt.hist(df2.Calificacion, bins=7)
plt.title("Calificaciones del grupo 2")
plt.axvline(media2, color='y', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.xlabel("Calificaciones")
# Out:
# Text(0.5, 0, 'Calificaciones')

# %%
#Generando histograma de calificaciones del grupo 3
from matplotlib import pyplot
media3=df3.Calificacion.mean()
plt.hist(df3.Calificacion, bins=7)
plt.title("Calificaciones del grupo 3")
plt.axvline(media3, color='y', linestyle='dashed', linewidth=2, label=f'Media={media3:.2f}')
plt.xlabel("Calificaciones")
# Out:
# Text(0.5, 0, 'Calificaciones')

# %% [markdown]
# Modelo de regresion lineal

# %%
#Entrenando un modelo de regresion lineal simple
from sklearn.linear_model import LinearRegression
import numpy as np
inversion_tiempo1=np.array(df1.HorasEstudio.tolist()).reshape(-1, 1)
calificacion1=df1.Calificacion.tolist()
modelo1=LinearRegression()
modelo1.fit(inversion_tiempo1, calificacion1)

#Obteniendo la ecuacion de la linea de regresion (pendiente e intercepto)
print("Coeficiente de la pendiente (m):", modelo1.coef_[0])
print("Intercepcion de la recta (b):", modelo1.intercept_)
# Out:
# Coeficiente de la pendiente (m): -0.10608151145860807
# Intercepcion de la recta (b): 85.31068185245395

# %%
#Entrenando un modelo de regresion lineal simple
from sklearn.linear_model import LinearRegression
import numpy as np
inversion_tiempo2=np.array(df2.HorasEstudio.tolist()).reshape(-1, 1)
calificacion2=df2.Calificacion.tolist()
modelo2=LinearRegression()
modelo2.fit(inversion_tiempo2, calificacion2)

#Obteniendo la ecuacion de la linea de regresion (pendiente e intercepto)
print("Coeficiente de la pendiente (m):", modelo2.coef_[0])
print("Intercepcion de la recta (b):", modelo2.intercept_)
# Out:
# Coeficiente de la pendiente (m): 4.222718653627889
# Intercepcion de la recta (b): 15.30754188313253

# %%
#Entrenando un modelo de regresion lineal simple
from sklearn.linear_model import LinearRegression
import numpy as np
inversion_tiempo3=np.array(df3.HorasEstudio.tolist()).reshape(-1, 1)
calificacion3=df3.Calificacion.tolist()
modelo3=LinearRegression()
modelo3.fit(inversion_tiempo3, calificacion3)

#Obteniendo la ecuacion de la linea de regresion (pendiente e intercepto)
print("Coeficiente de la pendiente (m):", modelo3.coef_[0])
print("Intercepcion de la recta (b):", modelo3.intercept_)
# Out:
# Coeficiente de la pendiente (m): 5.285670950508442
# Intercepcion de la recta (b): 0.10805051830283219

# %% [markdown]
# Calculo de la correlacion

# %%
#Calculando el coeficiente de correlacion de Pearson entre las horas de estudio y las calificaciones
from scipy.stats import pearsonr
coeficiente_correlacion, p_valor=pearsonr(df1.HorasEstudio.tolist(), calificacion1)
print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlacion de Pearson: -0.057133344466469324
# Valor p: 0.6935088469237538

# %%
#Calculando el coeficiente de correlacion de Pearson entre las horas de estudio y las calificaciones
from scipy.stats import pearsonr
coeficiente_correlacion, p_valor=pearsonr(df1.HorasEstudio.tolist(), calificacion2)
print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlacion de Pearson: -0.3117075359029713
# Valor p: 0.027553985134172284

# %%
#Calculando el coeficiente de correlacion de Pearson entre las horas de estudio y las calificaciones
from scipy.stats import pearsonr
coeficiente_correlacion, p_valor=pearsonr(df1.HorasEstudio.tolist(), calificacion3)
print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlacion de Pearson: -0.34572765720878396
# Valor p: 0.013925183587764928

# %% [markdown]
# Visualizacion de resultados

# %%
import seaborn as sns

#Incluyendo un grafico de dispersion Scatterplot
plt.figure(figsize=(6, 4))
inversion_tiempo=df1.HorasEstudio.tolist()
sns.set(style="whitegrid")
sns.regplot(x=inversion_tiempo, y=calificacion1, scatter=True, color='blue')
plt.title('Diagrama de dispersion con linea de regresion del grupo 1')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificaciones')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

#Incluyendo un grafico de dispersion Scatterplot
plt.figure(figsize=(6, 4))
inversion_tiempo=df2.HorasEstudio.tolist()
sns.set(style="whitegrid")
sns.regplot(x=inversion_tiempo, y=calificacion2, scatter=True, color='blue')
plt.title('Diagrama de dispersion con linea de regresion del grupo 2')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificaciones')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

#Incluyendo un grafico de dispersion Scatterplot
plt.figure(figsize=(6, 4))
inversion_tiempo=df3.HorasEstudio.tolist()
sns.set(style="whitegrid")
sns.regplot(x=inversion_tiempo, y=calificacion3, scatter=True, color='blue')
plt.title('Diagrama de dispersion con linea de regresion del grupo 3')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificaciones')
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretacion de los resultados

# %%
#1. ¿Explicar cuál es la interpretación del coeficiente de regresión en
#términos de la relación entre el tiempo de estudio y las calificaciones finales?
#La linea tiene una pendiente poco inclinada, indicando que es poco el cambio
#que la variable de las calificaciones tiene en funcion de que tantas horas se
#estudia.

#2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y
#dirección de la relación entre las variables?
#La alta dispersion de los datos hace que no haya correlacion.

#3. ¿El modelo de regresión lineal es estadísticamente significativo?
#No porque los datos estan demasiado dispersos, por que no estan en la linea.

#4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones
#finales de los estudiantes basado en el tiempo de estudio?
#En este caso es poco confiable, ya que por una u otra razon este grupo no mejora
#sus calificaciones en funcion del tiempo de estudio.

# %%
#1. ¿Explicar cuál es la interpretación del coeficiente de regresión en
#términos de la relación entre el tiempo de estudio y las calificaciones finales?
#La pendiente que nos da el coeficiente de correlacion nos habla de que en este
#grupo cuanto mas se estudia tiende a aumentar las probabilidades de exito en las
#calificaciones.

#2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y
#dirección de la relación entre las variables?
#Se podria decir que se trata de una correlacion positiva.

#3. ¿El modelo de regresión lineal es estadísticamente significativo?
#Mas o menos si, porque hay al menos una relacion entre los valores y la linea de
#regresion que de ellos se obtiene.

#4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones
#finales de los estudiantes basado en el tiempo de estudio?
#Es medianamente confiable pero puede ayudar en algo.

# %%
#1. ¿Explicar cuál es la interpretación del coeficiente de regresión en
#términos de la relación entre el tiempo de estudio y las calificaciones finales?
#Que las calificaciones obtenidas aumentan en funcion del tiempo de estudio.

#2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y
#dirección de la relación entre las variables?
#Es una relacion casi perfectamente positiva, lo quee significa que hay una
#buena relacion entre las calificaciones y el tiempoo de estudio.

#3. ¿El modelo de regresión lineal es estadísticamente significativo?
#Si porque la regresion lineal que se obtiene de esto es precisa sobre el valor
#que adquieren los datos obtenidos.

#4. ¿Qué tan confiable es el modelo de regresión para predecir lascalificaciones
#finales de los estudiantes basado en el tiempo de estudio?
#Es confiable porque los datos estadisticos se prestan bien para determinar que
#calificacion se podria obtener en funcion del tiempo de estudio.
